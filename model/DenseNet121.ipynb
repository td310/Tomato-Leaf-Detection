# %%
import os
import json
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import cv2

# %%
# ======= PATH ========
dataset_path = '/content/tomatoleaf/clean_tomato_dataset_td'
train_dir = os.path.join(dataset_path, 'train')
val_dir = os.path.join(dataset_path, 'val')

save_dir = "/content/drive/MyDrive/brain_model/DenseNet121_GradCAM"
os.makedirs(save_dir, exist_ok=True)

# %%
# ======= DATA AUGMENTATION ========
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(rescale=1./255)

batch_size = 32
image_size = (224, 224)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

class_indices = train_generator.class_indices
idx_to_class = {v: k for k, v in class_indices.items()}
# Out:
# Found 2240 images belonging to 8 classes.
# Found 391 images belonging to 8 classes.

# %%
# ======= MODEL ========
base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(len(class_indices), activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)
model.compile(optimizer=Adam(1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# ======= CALLBACKS ========
# Explanation: Updated paths for DenseNet121 weights and model.
checkpoint_path = os.path.join(save_dir, 'densenet121_best.weights.h5')
model_path = os.path.join(save_dir, 'densenet121_final.keras')

callbacks = [
    ModelCheckpoint(checkpoint_path, save_weights_only=True, monitor='val_accuracy', save_best_only=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, verbose=1),
    EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True, verbose=1)
]

# %%
# ======= TRAINING PHASE 1: Train top layers ========
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=10,
    callbacks=callbacks
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.2597 - loss: 2.2207
# Epoch 1: val_accuracy improved from -inf to 0.50639, saving model to /content/drive/MyDrive/brain_model/DenseNet121_GradCAM/densenet121_best.weights.h5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 81s 737ms/step - accuracy: 0.2603 - loss: 2.2175 - val_accuracy: 0.5064 - val_loss: 1.4832 - learning_rate: 1.0000e-04
# Epoch 2/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.4977 - loss: 1.4972
# Epoch 2: val_accuracy improved from 0.50639 to 0.67775, saving model to /content/drive/MyDrive/brain_model/DenseNet121_GradCAM/densenet121_best.weights.h5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 33s 475ms/step - accuracy: 0.4982 - loss: 1.4958 - val_accuracy: 0.6777 - val_loss: 1.1601 - learning_rate: 1.0000e-04
# Epoch 3/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.6099 - loss: 1.1835
# Epoch 3: val_accuracy improved from 0.67775 to 0.74680, saving model to /content/drive/MyDrive/brain_model/DenseNet121_GradCAM/densenet121_best.weights.h5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 31s 449ms/step - accuracy: 0.6101 - loss: 1.1828 - val_accuracy: 0.7468 - val_loss: 0.9709 - learning_rate: 1.0000e-04
# Epoch 4/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.6881 - loss: 0.9938
# Epoch 4: val_accuracy improved from 0.74680 to 0.76471, saving model to /content/drive/MyDrive/brain_model/DenseNet121_GradCAM/densenet121_best.weights.h5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 32s 464ms/step - accuracy: 0.6881 - loss: 0.9935 - val_accuracy: 0.7647 - val_loss: 0.8496 - learning_rate: 1.0000e-04
# Epoch 5/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.7224 - loss: 0.8602
# Epoch 5: val_accuracy improved from 0.76471 to 0.80818, saving model to /content/drive/MyDrive/brain_model/DenseNet121_GradCAM/densenet121_best.weights.h5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 31s 448ms/step - accuracy: 0.7223 - loss: 0.8602 - val_accuracy: 0.8082 - val_loss: 0.7477 - learning_rate: 1.0000e-04
# Epoch 6/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.7615 - loss: 0.7729
# Epoch 6: val_accuracy did not improve from 0.80818
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 30s 428ms/step - accuracy: 0.7614 - loss: 0.7729 - val_accuracy: 0.8005 - val_loss: 0.6943 - learning_rate: 1.0000e-04
# Epoch 7/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.7691 - loss: 0.7202
# Epoch 7: val_accuracy improved from 0.80818 to 0.81074, saving model to /content/drive/MyDrive/brain_model/DenseNet121_GradCAM/densenet121_best.weights.h5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 32s 457ms/step - accuracy: 0.7690 - loss: 0.7201 - val_accuracy: 0.8107 - val_loss: 0.6510 - learning_rate: 1.0000e-04
# Epoch 8/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.7787 - loss: 0.6665
# Epoch 8: val_accuracy improved from 0.81074 to 0.81841, saving model to /content/drive/MyDrive/brain_model/DenseNet121_GradCAM/densenet121_best.weights.h5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 32s 451ms/step - accuracy: 0.7788 - loss: 0.6664 - val_accuracy: 0.8184 - val_loss: 0.6090 - learning_rate: 1.0000e-04
# Epoch 9/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.8097 - loss: 0.5985
# Epoch 9: val_accuracy improved from 0.81841 to 0.83887, saving model to /content/drive/MyDrive/brain_model/DenseNet121_GradCAM/densenet121_best.weights.h5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 32s 454ms/step - accuracy: 0.8097 - loss: 0.5984 - val_accuracy: 0.8389 - val_loss: 0.5609 - learning_rate: 1.0000e-04
# Epoch 10/10
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - accuracy: 0.8206 - loss: 0.5511
# Epoch 10: val_accuracy did not improve from 0.83887
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 31s 436ms/step - accuracy: 0.8206 - loss: 0.5513 - val_accuracy: 0.8389 - val_loss: 0.5301 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 9.

# %%
# ======= TRAINING PHASE 2: Unfreeze and Fine-Tune ========
base_model.trainable = True
model.compile(optimizer=Adam(1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

fine_tune_history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=25,
    callbacks=callbacks
)
model.save(model_path)
# Out:
# Epoch 1/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - accuracy: 0.4787 - loss: 1.7519
# Epoch 1: val_accuracy improved from 0.83887 to 0.85422, saving model to /content/drive/MyDrive/brain_model/DenseNet121_GradCAM/densenet121_best.weights.h5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 215s 783ms/step - accuracy: 0.4800 - loss: 1.7471 - val_accuracy: 0.8542 - val_loss: 0.4921 - learning_rate: 1.0000e-05
# Epoch 2/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.7417 - loss: 0.7718
# Epoch 2: val_accuracy improved from 0.85422 to 0.86957, saving model to /content/drive/MyDrive/brain_model/DenseNet121_GradCAM/densenet121_best.weights.h5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 40s 566ms/step - accuracy: 0.7420 - loss: 0.7704 - val_accuracy: 0.8696 - val_loss: 0.4378 - learning_rate: 1.0000e-05
# Epoch 3/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.8333 - loss: 0.5038
# Epoch 3: val_accuracy improved from 0.86957 to 0.89514, saving model to /content/drive/MyDrive/brain_model/DenseNet121_GradCAM/densenet121_best.weights.h5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 40s 570ms/step - accuracy: 0.8336 - loss: 0.5030 - val_accuracy: 0.8951 - val_loss: 0.3665 - learning_rate: 1.0000e-05
# Epoch 4/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.9170 - loss: 0.3085
# Epoch 4: val_accuracy improved from 0.89514 to 0.91049, saving model to /content/drive/MyDrive/brain_model/DenseNet121_GradCAM/densenet121_best.weights.h5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 40s 572ms/step - accuracy: 0.9169 - loss: 0.3085 - val_accuracy: 0.9105 - val_loss: 0.2991 - learning_rate: 1.0000e-05
# Epoch 5/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.8961 - loss: 0.3052
# Epoch 5: val_accuracy improved from 0.91049 to 0.92839, saving model to /content/drive/MyDrive/brain_model/DenseNet121_GradCAM/densenet121_best.weights.h5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 40s 571ms/step - accuracy: 0.8963 - loss: 0.3047 - val_accuracy: 0.9284 - val_loss: 0.2499 - learning_rate: 1.0000e-05
# Epoch 6/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.9372 - loss: 0.2050
# Epoch 6: val_accuracy improved from 0.92839 to 0.94118, saving model to /content/drive/MyDrive/brain_model/DenseNet121_GradCAM/densenet121_best.weights.h5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 40s 576ms/step - accuracy: 0.9371 - loss: 0.2050 - val_accuracy: 0.9412 - val_loss: 0.2210 - learning_rate: 1.0000e-05
# Epoch 7/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - accuracy: 0.9467 - loss: 0.1844
# Epoch 7: val_accuracy improved from 0.94118 to 0.94885, saving model to /content/drive/MyDrive/brain_model/DenseNet121_GradCAM/densenet121_best.weights.h5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 40s 576ms/step - accuracy: 0.9467 - loss: 0.1844 - val_accuracy: 0.9488 - val_loss: 0.1943 - learning_rate: 1.0000e-05
# Epoch 8/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.9504 - loss: 0.1638
# Epoch 8: val_accuracy did not improve from 0.94885
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 37s 531ms/step - accuracy: 0.9504 - loss: 0.1638 - val_accuracy: 0.9412 - val_loss: 0.1805 - learning_rate: 1.0000e-05
# Epoch 9/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.9581 - loss: 0.1347
# Epoch 9: val_accuracy did not improve from 0.94885
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 35s 502ms/step - accuracy: 0.9581 - loss: 0.1347 - val_accuracy: 0.9437 - val_loss: 0.1710 - learning_rate: 1.0000e-05
# Epoch 10/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.9625 - loss: 0.1255
# Epoch 10: val_accuracy did not improve from 0.94885
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 42s 510ms/step - accuracy: 0.9625 - loss: 0.1254 - val_accuracy: 0.9463 - val_loss: 0.1595 - learning_rate: 1.0000e-05
# Epoch 11/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.9626 - loss: 0.1237
# Epoch 11: val_accuracy improved from 0.94885 to 0.95141, saving model to /content/drive/MyDrive/brain_model/DenseNet121_GradCAM/densenet121_best.weights.h5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 38s 544ms/step - accuracy: 0.9627 - loss: 0.1235 - val_accuracy: 0.9514 - val_loss: 0.1456 - learning_rate: 1.0000e-05
# Epoch 12/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.9733 - loss: 0.0950
# Epoch 12: val_accuracy improved from 0.95141 to 0.95652, saving model to /content/drive/MyDrive/brain_model/DenseNet121_GradCAM/densenet121_best.weights.h5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 40s 566ms/step - accuracy: 0.9733 - loss: 0.0951 - val_accuracy: 0.9565 - val_loss: 0.1420 - learning_rate: 1.0000e-05
# Epoch 13/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.9709 - loss: 0.0885
# Epoch 13: val_accuracy improved from 0.95652 to 0.95908, saving model to /content/drive/MyDrive/brain_model/DenseNet121_GradCAM/densenet121_best.weights.h5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 41s 574ms/step - accuracy: 0.9710 - loss: 0.0885 - val_accuracy: 0.9591 - val_loss: 0.1314 - learning_rate: 1.0000e-05
# Epoch 14/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.9809 - loss: 0.0743
# Epoch 14: val_accuracy did not improve from 0.95908
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 37s 523ms/step - accuracy: 0.9809 - loss: 0.0743 - val_accuracy: 0.9565 - val_loss: 0.1301 - learning_rate: 1.0000e-05
# Epoch 15/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.9690 - loss: 0.0956
# Epoch 15: val_accuracy improved from 0.95908 to 0.96164, saving model to /content/drive/MyDrive/brain_model/DenseNet121_GradCAM/densenet121_best.weights.h5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 39s 559ms/step - accuracy: 0.9690 - loss: 0.0953 - val_accuracy: 0.9616 - val_loss: 0.1274 - learning_rate: 1.0000e-05
# Epoch 16/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.9822 - loss: 0.0637
# Epoch 16: val_accuracy did not improve from 0.96164
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 37s 533ms/step - accuracy: 0.9821 - loss: 0.0637 - val_accuracy: 0.9591 - val_loss: 0.1211 - learning_rate: 1.0000e-05
# Epoch 17/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.9823 - loss: 0.0527
# Epoch 17: val_accuracy did not improve from 0.96164
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 36s 506ms/step - accuracy: 0.9823 - loss: 0.0527 - val_accuracy: 0.9591 - val_loss: 0.1155 - learning_rate: 1.0000e-05
# Epoch 18/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.9823 - loss: 0.0607
# Epoch 18: val_accuracy improved from 0.96164 to 0.96419, saving model to /content/drive/MyDrive/brain_model/DenseNet121_GradCAM/densenet121_best.weights.h5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 39s 547ms/step - accuracy: 0.9823 - loss: 0.0607 - val_accuracy: 0.9642 - val_loss: 0.1098 - learning_rate: 1.0000e-05
# Epoch 19/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9908 - loss: 0.0441
# Epoch 19: val_accuracy did not improve from 0.96419
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 39s 520ms/step - accuracy: 0.9908 - loss: 0.0442 - val_accuracy: 0.9642 - val_loss: 0.1167 - learning_rate: 1.0000e-05
# Epoch 20/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step - accuracy: 0.9894 - loss: 0.0476
# Epoch 20: val_accuracy did not improve from 0.96419
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 40s 507ms/step - accuracy: 0.9894 - loss: 0.0476 - val_accuracy: 0.9642 - val_loss: 0.1120 - learning_rate: 1.0000e-05
# Epoch 21/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.9932 - loss: 0.0414
# Epoch 21: val_accuracy did not improve from 0.96419
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 36s 510ms/step - accuracy: 0.9932 - loss: 0.0415 - val_accuracy: 0.9642 - val_loss: 0.1069 - learning_rate: 5.0000e-06
# Epoch 22/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - accuracy: 0.9853 - loss: 0.0465
# Epoch 22: val_accuracy did not improve from 0.96419
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 36s 517ms/step - accuracy: 0.9853 - loss: 0.0465 - val_accuracy: 0.9642 - val_loss: 0.1048 - learning_rate: 5.0000e-06
# Epoch 23/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - accuracy: 0.9876 - loss: 0.0360
# Epoch 23: val_accuracy did not improve from 0.96419
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 36s 513ms/step - accuracy: 0.9876 - loss: 0.0361 - val_accuracy: 0.9642 - val_loss: 0.1006 - learning_rate: 5.0000e-06
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 18.

# %%
# ======= Visualize Training ========
def plot_training_history(history1, history2=None):
    acc = history1.history['accuracy']
    val_acc = history1.history['val_accuracy']
    loss = history1.history['loss']
    val_loss = history1.history['val_loss']

    if history2:
        acc += history2.history['accuracy']
        val_acc += history2.history['val_accuracy']
        loss += history2.history['loss']
        val_loss += history2.history['val_loss']

    epochs_range = range(len(acc))

    plt.figure(figsize=(14, 5))

    # Accuracy plot
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    # Loss plot
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')

    plt.tight_layout()
    plt.show()

plot_training_history(history, fine_tune_history)
